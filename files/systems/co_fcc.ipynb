# %%
from modules import create_emto_inputs
import os
 
emto_inputs = {
    "output_path": "Co_hcp",
    "job_name": "Co",
    "cif_file": None,
    "lat": 4,
    "a": 2.47,
    "sites": [{"position": [0, 0, 0], 'elements': ['Co'], 'concentrations': [1.0]},
              {"position": [0.666667, 0.333333, 0.500000], 'elements': ['Co'], 'concentrations': [1.0]}],
    "dmax": 2.4,
    "ca_ratios": [1.4,1.5,1.6,1.7,1.8],
    "sws_values": [2.6],
    "magnetic": 'F',
    "user_magnetic_moments": None,
    "create_job_script": True,
    "job_mode": "serial",
    "prcs": 8,
    "time": "00:30:00",
    "account": "naiss2025-1-38",
    "optimize_dmax": False,
    "dmax_initial": 3,
    "dmax_target_vectors": 100,
    "dmax_vector_tolerance": 15,
    "kstr_executable": "/home/x_pamca/postdoc_proj/emto/bin/kstr.exe"
}

emto_inputs["output_path"] = os.path.join(emto_inputs["output_path"], "ratio_ca")

create_emto_inputs(config=emto_inputs)
# Out:
# Created directory structure in: Co_hcp/ratio_ca
#
# Creating structure from parameters...
#   Lattice type: LAT=4
#   Lattice parameter a: 2.47 Å
#   Number of sites: 2
#   Structure created: LAT=4 (Hexagonal)
#   Number of atoms: NQ3=2
#   Maximum NL: 3
#
# Creating input files for 5 c/a ratios and 1 SWS values...
#
#   c/a = 1.40
# KSTR input file 'Co_hcp/ratio_ca/smx/Co_1.40.dat' created successfully.
# SHAPE input file 'Co_hcp/ratio_ca/shp/Co_1.40.dat' created successfully.
# KGRN input file 'Co_hcp/ratio_ca/Co_1.40_2.60.dat' created successfully.
# KFCD input file 'Co_hcp/ratio_ca/fcd/Co_1.40_2.60.dat' created successfully.
#
#   c/a = 1.50
# KSTR input file 'Co_hcp/ratio_ca/smx/Co_1.50.dat' created successfully.
# SHAPE input file 'Co_hcp/ratio_ca/shp/Co_1.50.dat' created successfully.
# KGRN input file 'Co_hcp/ratio_ca/Co_1.50_2.60.dat' created successfully.
# KFCD input file 'Co_hcp/ratio_ca/fcd/Co_1.50_2.60.dat' created successfully.
#
#   c/a = 1.60
# KSTR input file 'Co_hcp/ratio_ca/smx/Co_1.60.dat' created successfully.
# SHAPE input file 'Co_hcp/ratio_ca/shp/Co_1.60.dat' created successfully.
# KGRN input file 'Co_hcp/ratio_ca/Co_1.60_2.60.dat' created successfully.
# KFCD input file 'Co_hcp/ratio_ca/fcd/Co_1.60_2.60.dat' created successfully.
#
#   c/a = 1.70
# KSTR input file 'Co_hcp/ratio_ca/smx/Co_1.70.dat' created successfully.
# SHAPE input file 'Co_hcp/ratio_ca/shp/Co_1.70.dat' created successfully.
# KGRN input file 'Co_hcp/ratio_ca/Co_1.70_2.60.dat' created successfully.
# KFCD input file 'Co_hcp/ratio_ca/fcd/Co_1.70_2.60.dat' created successfully.
#
#   c/a = 1.80
# KSTR input file 'Co_hcp/ratio_ca/smx/Co_1.80.dat' created successfully.
# SHAPE input file 'Co_hcp/ratio_ca/shp/Co_1.80.dat' created successfully.
# KGRN input file 'Co_hcp/ratio_ca/Co_1.80_2.60.dat' created successfully.
# KFCD input file 'Co_hcp/ratio_ca/fcd/Co_1.80_2.60.dat' created successfully.
#
# Creating serial job script...
# Created serial job script: Co_hcp/ratio_ca/run_Co.sh
# To submit: sbatch run_Co.sh
#
# ======================================================================
# WORKFLOW COMPLETE
# ======================================================================
# Files created:
#   KSTR:  5 files in Co_hcp/ratio_ca/smx/
#   SHAPE: 5 files in Co_hcp/ratio_ca/shp/
#   KGRN:  5 files in Co_hcp/ratio_ca/
#   KFCD:  5 files in Co_hcp/ratio_ca/fcd/
# ======================================================================

# %%
from modules import create_emto_inputs
import os
 
emto_inputs = {
    "output_path": "CuMg_fcc",
    "job_name": "CuMg",
    "cif_file": None,
    "lat": 2,
    "a": 3.6,
    "sites": [{"position": [0, 0, 0], 'elements': ['Cu', 'Mg'], 'concentrations': [0.2, 0.8]}],
    "dmax": 1.8,
    "ca_ratios": None,
    "sws_values": [2.45, 2.50, 2.55, 2.6, 2.65, 2.70],
    "magnetic": 'F',
    "user_magnetic_moments": None,
    "create_job_script": True,
    "job_mode": "serial",
    "prcs": 8,
    "time": "00:30:00",
    "account": "naiss2025-1-38",
    "optimize_dmax": False,
    "dmax_initial": 2.5,
    "dmax_target_vectors": 100,
    "dmax_vector_tolerance": 15,
    "kstr_executable": "/home/x_pamca/postdoc_proj/emto/bin/kstr.exe"
}

emto_inputs["output_path"] = os.path.join(emto_inputs["output_path"], "sws_optimization")

create_emto_inputs(config=emto_inputs)
# Out:
# Created directory structure in: CuMg_fcc/sws_optimization
#
# Creating structure from parameters...
#   Lattice type: LAT=2
#   Lattice parameter a: 3.6 Å
#   Number of sites: 1
#   Structure created: LAT=2 (Face-centered cubic)
#   Number of atoms: NQ3=1
#   Maximum NL: 3
#
# Creating input files for 1 c/a ratios and 6 SWS values...
#
#   c/a = 1.00
# KSTR input file 'CuMg_fcc/sws_optimization/smx/CuMg_1.00.dat' created successfully.
# SHAPE input file 'CuMg_fcc/sws_optimization/shp/CuMg_1.00.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.45.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.45.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.50.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.50.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.55.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.55.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.60.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.60.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.65.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.65.dat' created successfully.
# KGRN input file 'CuMg_fcc/sws_optimization/CuMg_1.00_2.70.dat' created successfully.
# KFCD input file 'CuMg_fcc/sws_optimization/fcd/CuMg_1.00_2.70.dat' created successfully.
#
# Creating serial job script...
# Created serial job script: CuMg_fcc/sws_optimization/run_CuMg.sh
# To submit: sbatch run_CuMg.sh
#
# ======================================================================
# WORKFLOW COMPLETE
# ======================================================================
# Files created:
#   KSTR:  1 files in CuMg_fcc/sws_optimization/smx/
#   SHAPE: 1 files in CuMg_fcc/sws_optimization/shp/
#   KGRN:  6 files in CuMg_fcc/sws_optimization/
#   KFCD:  6 files in CuMg_fcc/sws_optimization/fcd/
# ======================================================================

# %%
from utils.running_bash import run_sbatch, chmod_and_run

chmod_and_run("run_Co.sh", path = emto_inputs['output_path'], stdout_file="Co_output.log", stderr_file="Co_error.log")
# Out:
# Making script executable and running...
# Running finished successfully

# %%
import os
os.path.join(emto_inputs["output_path"], "ratio_ca")
# Out:
# 'Co_hcp/ratio_ca'
